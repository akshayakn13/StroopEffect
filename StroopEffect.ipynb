# %% [markdown]
# # Stroop Effect

# %% [markdown]
# ## Background Information
#
# In a Stroop task, participants are presented with a list of words, with each word displayed in a color of ink. The participant’s task is to say out loud the color of the ink in which the word is printed. The task has two conditions: a **congruent words condition**, and an **incongruent words condition**. In the **congruent words** condition, the words being displayed are color words whose names match the colors in which they are printed: for example RED, BLUE. In the **incongruent words condition**, the words displayed are color words whose names do not match the colors in which they are printed: for example PURPLE, ORANGE. In each case, we measure the time it takes to name the ink colors in equally-sized lists. Each participant will go through and record a time from each condition.

# %%
from IPython.display import Image
Image(filename='D:/firefox downloads/stroop.png')

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import math 
import seaborn as sns 
import math

# %%
data = {
    "Congruent": [12.079,16.791,9.564,8.63,14.669,12.238,14.692,8.987,9.401,14.48,22.328,15.298,15.073,16.929,18.2,12.13,18.495,10.639,11.344,12.369,12.944,14.233,19.71,16.004],
"Incongruent":[19.278,18.741,21.214,15.687,22.803,20.878,24.572,17.394,20.762,26.282,24.524,18.644,17.51,20.33,35.255,22.158,25.139,20.429,17.425,34.288,23.894,17.96,22.058,21.157]}

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    Congruent  Incongruent
# 0     12.079       19.278
# 1     16.791       18.741
# 2      9.564       21.214
# 3      8.630       15.687
# 4     14.669       22.803

# %% [markdown]
# ## Questions For Investigation

# %% [markdown]
# ### What is our independent variable? What is our dependent variable?

# %% [markdown]
# **Independent Variable =** An independent variable is the variable that is changed or controlled in a scientific settings to see the effects on the dependent variable.Here the independent variable is **congruent and incongruent words**.
#
#
# **Dependent Variable =** Variable on which the effect can be seen due to the change on independent variable. Here the dependent variable is the **respone time** for each participant.

# %% [markdown]
# ### What is an appropriate set of hypotheses for this task? What kind of statistical test do you expect to perform? Justify your choices.

# %% [markdown]
# I choose two-tailed t-test as the appropriate set of hypothesis for this task to measure that the two conditions are statistically different to each other or not
#
# **Reason for selecting the following statistical task**
#
# 1. We don't know the population parameters, we just have 24 samples.
#
# 2. we don't the direction of the test so we chose two tailed t-test to test wether the two conditions are statistically different or not.

# %% [markdown]
# **Null-Hypothesis:** There is no difference in the response time of the participant during both the conditions i.e incongruent and congruent.
# Ho : mean of congruent words - mean of incongruent words = 0
#
# **Alternative Hypothesis:** There is no difference in the response time of the participant during both the conditions i.e incongruent and congruent.
# Ha : mean of congruent words - mean of incongruent words > 0
#
#
#
#
# Ho ( Null Hypothesis )       :  (Population Mean)incongruent   =   (Population Mean)  congruent  OR      **μi=μc**
#
# Ha( Alternative Hypothesis )   :  (Population Mean)incongruent   ≠  (Population Mean)  congruent   OR   **μi ≠ μc**
#
# Where,
#
# μi= Mean time taken to name the ink color for incongruent words.
#
#
# μc= Mean time taken to name the ink color for congruent words

# %% [markdown]
# ### Report some descriptive statistics regarding this dataset. Include at least one measure of central tendency and at least one measure of variability.

# %%
df.describe()
# Out:
#        Congruent  Incongruent
# count  24.000000    24.000000
# mean   14.051125    22.015917
# std     3.559358     4.797057
# min     8.630000    15.687000
# 25%    11.895250    18.716750
# 50%    14.356500    21.017500
# 75%    16.200750    24.051500
# max    22.328000    35.255000

# %%
df.median()
# Out:
# Congruent      14.3565
# Incongruent    21.0175
# dtype: float64

# %% [markdown]
# **Measure of central tendency**
# 1. Congruent - Mean= 14.05 and Median = 14.35 ; Standard Deviation = 3.55
#
# 2. InCongruent - Mean= 22.02 and Median = 21.02 ; Standard Deviation = 4.79

# %% [markdown]
# ### Provide one or two visualizations that show the distribution of the sample data. Write one or two sentences noting what you observe about the plot or plots.

# %%
#Make a boxplot for both datasets
sns.set_style("whitegrid")
sns.boxplot(data=df[['Congruent', 'Incongruent']], orient="v",width=0.4, palette="colorblind");
plt.ylabel("Time");

# %% [markdown]
# 1. The box-plot clearly shows the difference between the medians of the two conditions, which we already seen in the descriptive analysis. Which means that on average participants took more time in incongruent condition than congruent condition
#
# 2. We can also see the presence of some **outliers** in the incongruent word condtions, which means out of 24 two participant took around 35unit of time

# %%
#Plot a Graph for congruent dataset
sns.distplot(df['Congruent'])
plt.xlabel("Time");
plt.ylabel("Frequency");
plt.title("Response Time for Congruent Words");

# %% [markdown]
# Response time for congruent words shows a **normal distribution with mean around 14**

# %%
#Plot a Graph for congruent dataset
sns.distplot(df['Incongruent'])
plt.xlabel("Time");
plt.ylabel("Frequency");
plt.title("Response Time for Incongruent Words");
plt.show()

# %% [markdown]
# Response time for congruent words shows a **normal distribution with mean around 21** also there is a little bump at 35 time axis which shows the outliers we talked earlier

# %%
sns.distplot(df['Congruent'],label = "Congruent")
sns.distplot(df['Incongruent'],label = "Incongruent")
plt.xlabel("Time");
plt.ylabel("Frequency");
plt.title("Response Time For Congruent Vs Incongruent Words");
plt.legend();

# %% [markdown]
# ### Now, perform the statistical test and report your results. What is your confidence level and your critical statistic value? Do you reject the null hypothesis or fail to reject it? Come to a conclusion in terms of the experiment task. Did the results match up with your expectations?

# %% [markdown]
# **Confidence Interval** = 95%
#
#
#
# **alpha level** = 0.025 for two tailed t-test
#
#
#
# **Degree of freedom** = n1 + n2 - 2 => 24+24 - 2

# %% [markdown]
# **Pooled Variance(Sp^2)** = (SScongruent + SSincongruent)/(degree of freedom)
#
#
# where , SS is the sum of square

# %%
## Calculating sum of squares
mean_congruent = df["Congruent"].mean()
ss_cong =0 
for i in df["Congruent"]:
    ss_cong += (i-mean_congruent)**2
    
print(mean_congruent)
print(ss_cong)
# Out:
# 14.051125
# 291.38766862500006

# %%
## Calculating sum of squares
mean_incongruent = df["Incongruent"].mean()
ss_incong =0 
for i in df["Incongruent"]:
    ss_incong += (i-mean_incongruent)**2
    
print(mean_incongruent)
print(ss_incong)
# Out:
# 22.01591666666667
# 529.2704118333334

# %%
## Calculating pooled variance 
n1 = df["Congruent"].count()
n2 = df["Incongruent"].count()

print(f"No of sample in congruent = {n1} , incongruent = {n2}")
pooled_var = (ss_cong+ss_incong)/(n1 + n2 -2)

print(pooled_var)
# Out:
# No of sample in congruent = 24 , incongruent = 24
# 17.840393053442032

# %% [markdown]
# **Standard Error** = root((2sp^2)/(n1+n2))

# %%
## Calculating standard error 
SE = math.sqrt((2*(pooled_var**2))/(n1+n2))
print(SE)
# Out:
# 3.6416549826355435

# %% [markdown]
# **t-statistics =** difference(mean of incongruent, mean of congruent)/(standard error)

# %%
#calculating t-statistics 

t= (mean_incongruent - mean_congruent)/SE

print(f"t-statistics is +-{t}")
# Out:
# t-statistics is +-2.187135163722286

# %% [markdown]
# **t-critical value for a two-tailed t-test with degree of freedom = 46 is +- 1.684**
#
#
# Since p-value lies in the critical region we can say that t-value is statistically significant at the alpha level = 0.05 and hence **We reject the null hypothesis that means we accept the alternative hypothesis**

# %% [markdown]
# ### What do you think is responsible for the effects observed? Can you think of an alternative or similar task that would result in a similar effect? Some research about the problem will be helpful for thinking about these two questions?
#
# As habitual readers, we encounter and comprehend words on such a persistent basis that the reading occurs almost effortlessly, whereas declaration of a color requires more cognitive effort. When there is a conflict between these two sources of information, our cognitive load is increased, and our brains have to work harder to resolve the required difference. Performing these tasks (preventing reading, processing word color, and resolving information conflict) ultimately slows down our responses, and makes the task take longer.
#
# Reference - https://imotions.com/blog/the-stroop-effect/
#
# Similar effect to the this effect can be reserve stroop effect.In this test the participant’s task is to say out loud the word that is printed not its color.
